# %% [markdown]
# ### pandas
#
# pandas is a powerfull phython library for manipulation are alanaysis pf publish_display_data
#
#     its a open source library
#
# fast(build on top of numpy) , flexible(different resource), productive library

# %% [markdown]
# install

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
s= pd.Series(1, index = ["a","b","c","d","e"], name = "My series")

# %%
s
# Out:
# a    1
# b    1
# c    1
# d    1
# e    1
# Name: My series, dtype: int64

# %%
s['a']
# Out:
# np.int64(1)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# note : index in series are imuutable(cant change)

# %%
s.values
# Out:
# array([1, 1, 1, 1, 1])

# %%
#changing the index of a pandas series

s.rename(index={'b':'y'})
# Out:
# a    1
# y    1
# c    1
# d    1
# e    1
# Name: My series, dtype: int64

# %%
s
# Out:
# a    1
# b    1
# c    1
# d    1
# e    1
# Name: My series, dtype: int64

# %% [markdown]
# ### DataFrame - Its a 2d array (just like tables)

# %%
dict1 = {'Name':['Virat','Rohit','Dhoni','Jadeja','Bumrah'],
         'Age':[34,33,40,32,30],
         'Role':['Batsman','Batsman','Wicket keeper','All Rounder','Bowler']
}
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      Name  Age           Role
# 0   Virat   34        Batsman
# 1   Rohit   33        Batsman
# 2   Dhoni   40  Wicket keeper
# 3  Jadeja   32    All Rounder
# 4  Bumrah   30         Bowler

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.count()
# Out:
# Name    5
# Age     5
# Role    5
# dtype: int64

# %%
df.head(4)
# Out:
#      Name  Age           Role
# 0   Virat   34        Batsman
# 1   Rohit   33        Batsman
# 2   Dhoni   40  Wicket keeper
# 3  Jadeja   32    All Rounder

# %%
df.tail(4)
# Out:
#      Name  Age           Role
# 1   Rohit   33        Batsman
# 2   Dhoni   40  Wicket keeper
# 3  Jadeja   32    All Rounder
# 4  Bumrah   30         Bowler

# %%
len(df)
# Out:
# 5

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Role'], dtype='object')

# %%
df['Name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     Virat
# 1     Rohit
# 2     Dhoni
# 3    Jadeja
# 4    Bumrah
# Name: Name, dtype: object>

# %% [markdown]
# ### Basic Operations
#
# > Importing data set from diffrent files
#
#
# > Importing tabular dataset

# %%
stock_df = pd.read_csv(r"C:\Users\klemp\Desktop\data analyst (vinayak)\datasets\ETH_1h.csv")

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %% [markdown]
# # Top 5 rows

# %%
stock_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %% [markdown]
# # Top 10 rows

# %%
stock_df.head(10)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 5  2020-03-13 03-PM  ETHUSD  128.39  128.90  116.06  124.85  7378976.00
# 6  2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 7  2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 8  2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# 9  2020-03-13 11-AM  ETHUSD  132.60  133.17  126.01  128.93  3311080.29

# %% [markdown]
# # Bottom 5 rows

# %%
stock_df.tail()
# Out:
#                    Date  Symbol    Open    High    Low   Close      Volume
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.0  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.0  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.1  275.01   679358.87

# %%
## Number of rows in dataframe

len(stock_df)
# Out:
# 23674

# %% [markdown]
# # Access column name of DataFrame

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
## Accessing a column in DataFrame

stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
## Accessing multiple columns in DataFrame

stock_df[['Open','Close','Volume']]
# Out:
#          Open   Close      Volume
# 0      129.94  128.71  1940673.93
# 1      119.51  129.94  7579741.09
# 2      124.47  119.51  4898735.81
# 3      124.08  124.47  2753450.92
# 4      124.85  124.08  4461424.71
# ...       ...     ...         ...
# 23669  265.74  272.57  1500282.55
# 23670  268.79  265.74  1702536.85
# 23671  274.83  268.79  3010787.99
# 23672  275.01  274.83   824362.87
# 23673  279.98  275.01   679358.87
#
# [23674 rows x 3 columns]

# %% [markdown]
# # Assecing Rows

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %% [markdown]
# # Assccing Rows
#
# loc - lable location

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.loc[23673,['Date','Close','Open']]
# Out:
# Date     2017-07-01 11-AM
# Close              275.01
# Open               279.98
# Name: 23673, dtype: object

# %%
stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
stock_df.loc[23673,'Open':'Close']  # a:b
# Out:
# Open     279.98
# High     279.99
# Low       272.1
# Close    275.01
# Name: 23673, dtype: object

# %% [markdown]
# # iloc- index based location ,when we don't know labels for rows  and columns

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.iloc[1]
# Out:
# Date      2020-03-13 07-PM
# Symbol              ETHUSD
# Open                119.51
# High                132.02
# Low                  117.1
# Close               129.94
# Volume          7579741.09
# Name: 1, dtype: object

# %%
stock_df.iloc[1,2]
# Out:
# np.float64(119.51)

# %%
stock_df.iloc[3,[2,4]]
# Out:
# Open    124.08
# Low     121.63
# Name: 3, dtype: object

# %%
stock_df.iloc[2,2:6]
# Out:
# Open     124.47
# High     124.85
# Low       115.5
# Close    119.51
# Name: 2, dtype: object

# %%
stock_df.iloc[2:6,2:6]
# Out:
#      Open    High     Low   Close
# 2  124.47  124.85  115.50  119.51
# 3  124.08  127.42  121.63  124.47
# 4  124.85  129.51  120.17  124.08
# 5  128.39  128.90  116.06  124.85

# %% [markdown]
# # Filtering

# %%
f1 = stock_df

# %%
f1 = stock_df['High'] > 130 
 
stock_gt_130 = stock_df[f1]

# %%
stock_gt_130 = stock_df

# %%
stock_gt_130.reset_index(drop=True,inplace=True)

# %% [markdown]
# # Adding new column

# %%
stock_df.iloc[len(stock_df)-1]
# Out:
# Date      2017-07-01 11-AM
# Symbol              ETHUSD
# Low                  272.1
# Close               275.01
# Volume           679358.87
# Name: 23673, dtype: object

# %%
len(stock_df)
# Out:
# 23674

# %%
for i in range(0,3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
range(1,len(stock_df)+1)
# Out:
# range(1, 23675)

# %%
stock_df['Random_col']=list(range(1,len(stock_df)+1))

# %%
stock_df
# Out:
#                    Date  Symbol     Low   Close      Volume  Random_col
# 0      2020-03-13 08-PM  ETHUSD  126.87  128.71  1940673.93           1
# 1      2020-03-13 07-PM  ETHUSD  117.10  129.94  7579741.09           2
# 2      2020-03-13 06-PM  ETHUSD  115.50  119.51  4898735.81           3
# 3      2020-03-13 05-PM  ETHUSD  121.63  124.47  2753450.92           4
# 4      2020-03-13 04-PM  ETHUSD  120.17  124.08  4461424.71           5
# ...                 ...     ...     ...     ...         ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.00  272.57  1500282.55       23670
# 23670  2017-07-01 02-PM  ETHUSD  265.00  265.74  1702536.85       23671
# 23671  2017-07-01 01-PM  ETHUSD  265.00  268.79  3010787.99       23672
# 23672  2017-07-01 12-PM  ETHUSD  271.00  274.83   824362.87       23673
# 23673  2017-07-01 11-AM  ETHUSD  272.10  275.01   679358.87       23674
#
# [23674 rows x 6 columns]

# %% [markdown]
# # Dropping column

# %%
stock_df.drop(columns=['Random_col'],inplace=True)

# %%
stock_df
# Out:
#                    Date  Symbol     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  272.10  275.01   679358.87
#
# [23674 rows x 5 columns]

# %%
stock_df.drop(columns=['Volume'],inplace=True)

# %%
stock_df
# Out:
#                    Date  Symbol     Low   Close
# 0      2020-03-13 08-PM  ETHUSD  126.87  128.71
# 1      2020-03-13 07-PM  ETHUSD  117.10  129.94
# 2      2020-03-13 06-PM  ETHUSD  115.50  119.51
# 3      2020-03-13 05-PM  ETHUSD  121.63  124.47
# 4      2020-03-13 04-PM  ETHUSD  120.17  124.08
# ...                 ...     ...     ...     ...
# 23669  2017-07-01 03-PM  ETHUSD  265.00  272.57
# 23670  2017-07-01 02-PM  ETHUSD  265.00  265.74
# 23671  2017-07-01 01-PM  ETHUSD  265.00  268.79
# 23672  2017-07-01 12-PM  ETHUSD  271.00  274.83
# 23673  2017-07-01 11-AM  ETHUSD  272.10  275.01
#
# [23674 rows x 4 columns]
