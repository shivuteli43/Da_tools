# %%
# 1 * Numpy is a nultuim arraya

# %%
import math

math.sqrt(4)

# %%
! pip install numpy

# %%
! pip install numpy

# %%
import math
math.sqrt(16)

# %%
type(np4tn)

# %%
l1 = [21,12,'hello world']

# %%
type(l1)

# %% [markdown]
# converting python list to numpy array

# %%
np.array(l1)

# %%
type(l1)

# %%
np.array(l1)

# %%
l2 = np.array

# %%
arr1 = np.array([1,2,3,4,5,'hello world'])

# %%
type(arr1)

# %%
np.array([[1,3,2,1],
       [4,3,2,1]])

# %%
b = np.array([[1,3,2,1],
              [4,3,2,1]])
b.shape

# %%
b[0,1:3]=[2,3]

# %%
b
# Out:
# array([[1. , 2. , 3. , 5.8],
#        [2.1, 3. , 4.2, 4.5]])

# %%
b.itemsize*b.size
# Out:
# 64

# %%
np.int64(3)
# Out:
# np.int64(3)

# %%
l = [1,2,3,4,5,5]

# %%
l = [1,2,3,4,5,5]
l[1:3]
# Out:
# [2, 3]

# %%
#Numpy -> its a multidimensional array librabry .i,e u can store all sort of data.like 1-d,2-d,n-d;
#downloading Numpy(remeber to pip or pip3 install numpy first on terminal)

# %%
import numpy as np

# %%
#initialize array
a=np.array([1,2,3],dtype="int16") # with assigning to dtype i,e keyword argument we  can make it possible to store our data in specified number of bytes
#but it need to fit into that specified byte of storage; 
print("one dimensional array :",a)
# Out:
# one dimensional array : [1 2 3]

# %%
b=np.array([[1.0,2.0,3.0,5.8],[2.1,3,4.2,4.5]])
print("two dimensional array :",b)
# Out:
# two dimensional array : [[1.  2.  3.  5.8]
#  [2.1 3.  4.2 4.5]]

# %%
#Get Dimension
print("dimension of a :",a.ndim)
print("dimension of b :",b.ndim)
# Out:
# dimension of a : 1
# dimension of b : 2

# %%
#Get Shape
print("shape of a :",a.shape) #its a vector so its tellings us one dimension 
print("shape of b :",b.shape)
# Out:
# shape of a : (3,)
# shape of b : (2, 4)

# %%
#Get  Type
print("a type is :",a.dtype)
# Out:
# a type is : int16

# %%
#Get Size
print("size of a :",a.size) # # of element in the array.i,e length of array;
# Out:
# size of a : 3

# %%
#total size
print("a item size :",a.itemsize) # size of single element in the array .i,e in bytes;
print("total size is a:",a.size*a.itemsize)
# Out:
# a item size : 2
# total size is a: 6

# %%
#ACCESSING/CHANGING SPECIFIC ELEMENTS,ROWS,COLUMNS ETC

# %%
#Get specific element [row,column] -ve index is possible similar to list;
b[1,2]
# Out:
# np.float64(4.2)

# %%
#Get specific row [row,:]#we use slicing(:) operation
print("row :",b[1,0:1]);
# Out:
# row : [2.1]

# %%
#Get specific column[:,column]
print("column :",b[:,1])
# Out:
# column : [2. 3.]

# %%
#Getting a little more fancy [starindex:endindex:steps]
print("subset of specific row",b[1,1::2])
# Out:
# subset of specific row [3.  4.5]

# %%
#change element
b[1,2]=8
print(b)
# Out:
# [[1.  2.  3.  5.8]
#  [2.1 3.  8.  4.5]]

# %%
b[:,2]=[9,4]
b
# Out:
# array([[1. , 2. , 9. , 5.8],
#        [2.1, 3. , 4. , 4.5]])

# %% [markdown]
# 3-d exmaple

# %%
c=np.array([[
[1,2],[3,4]
  ],
  [
      [5,6],[7,8]
  ]
])

# %%
c
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
 type(c)
# Out:
# numpy.ndarray

# %%
c.shape
# Out:
# (2, 2, 2)

# %%
c.size
# Out:
# 8

# %% [markdown]
# ## calculate the memory space took for c numpy array

# %%
c.dtype
# Out:
# dtype('int64')

# %%
c.itemsize * c.size
# Out:
# 64

# %%
c
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
#get specific element (work outside in)
print("specified element is :",c[0,1,1])
# Out:
# specified element is : 4

# %%
zm = np.zeros((3,4)) #3 rows and 4 columns

# %%
zm.ndim
# Out:
# 2

# %%
zm.shape
# Out:
# (3, 4)

# %% [markdown]
# All 1's matrixs

# %%
np.ones ((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
#Any other number
np.full((4,5),100,dtype="float")
# Out:
# array([[100., 100., 100., 100., 100.],
#        [100., 100., 100., 100., 100.],
#        [100., 100., 100., 100., 100.],
#        [100., 100., 100., 100., 100.]])

# %%
np.full_like(100,200,dtype="float")
# Out:
# array(200.)

# %% [markdown]
# Random matrixs

# %%
np.random.random_sample((2,3))
# Out:
# array([[0.64980998, 0.35873352, 0.15783363],
#        [0.56254201, 0.35289784, 0.95905928]])

# %%
np.random.rand(2,3)
# Out:
# array([[0.22593619, 0.0010927 , 0.8975448 ],
#        [0.83843156, 0.65728537, 0.15329212]])

# %%
np.random.randint(2,9,size=(3,3))
# Out:
# array([[6, 7, 7],
#        [5, 8, 3],
#        [6, 5, 8]], dtype=int32)

# %%
#Generate identity matrix only one argument bcoz identity matrix is a
np.identity(0)# 5,5''
# Out:
# array([], shape=(0, 0), dtype=float64)
